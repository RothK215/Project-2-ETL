# %%
import pandas as pd

# %% [markdown]
# # **_New York City Inspection_**

# %%
# New York City Inscpection CSV
nyc = "Resources/DOHMH_New_York_City_Restaurant_Inspection_Results.csv"
nyc_df = pd.read_csv(nyc)
nyc_df.head()
# Out:
#       CAMIS                      DBA           BORO BUILDING         STREET  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS     2507       BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND      11C    HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN     8015       5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  10016.0  2126863400             Italian      06/15/2015
# 1  10016.0  2126863400             Italian      11/25/2014
# 2  11106.0  3478134702             Italian      10/03/2016
# 3  10314.0  7189839854             Chinese      05/17/2017
# 4  11209.0  7187019180            American      03/30/2017
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1  Violations were cited in the following area(s).            20F
# 2  Violations were cited in the following area(s).            10F
# 3  Violations were cited in the following area(s).            02G
# 4  Violations were cited in the following area(s).            04M
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0        Hot food item not held at or above 140Âº F.      Critical   30.0
# 1              Current letter grade card not posted.  Not Critical    NaN
# 2  Non-food contact surface improperly constructe...  Not Critical    2.0
# 3  Cold food item held above 41Âº F (smoked fish ...      Critical   46.0
# 4  Live roaches present in facility's food and/or...      Critical   18.0
#
#   GRADE GRADE DATE RECORD DATE  \
# 0   NaN        NaN  08/28/2017
# 1   NaN        NaN  08/28/2017
# 2   NaN        NaN  08/28/2017
# 3   NaN        NaN  08/28/2017
# 4   NaN        NaN  08/28/2017
#
#                                      INSPECTION TYPE
# 0              Cycle Inspection / Initial Inspection
# 1  Administrative Miscellaneous / Initial Inspection
# 2      Pre-permit (Operational) / Initial Inspection
# 3      Pre-permit (Operational) / Initial Inspection
# 4              Cycle Inspection / Initial Inspection

# %%
# Create Copy of original CSV
nycdf = nyc_df.copy()

# %%
# Drop any duplicate rows.
nycdf = nycdf.drop_duplicates()

# Replace any missing zipcode with 0 and Remove decimal place in zip code.
nycdf['ZIPCODE'] = nycdf['ZIPCODE'].fillna(0)
nycdf['ZIPCODE'] = nycdf['ZIPCODE'].astype(int)

# Merge Building with Street in one called Address
nycdf['ADDRESS'] = nycdf['BUILDING'] + f" " + nycdf['STREET']

# Unselect Building and Street columns
nycdf = nycdf[['CAMIS', 'DBA', 'BORO', 'ADDRESS', 'ZIPCODE', 'PHONE', 'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 
               'VIOLATION CODE', 'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE', 'GRADE DATE', 'RECORD DATE',
               'INSPECTION TYPE']]

nycdf.head()
# Out:
#       CAMIS                      DBA           BORO            ADDRESS  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN  635 SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN  635 SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS      2507 BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND    11C HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN      8015 5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0    10016  2126863400             Italian      06/15/2015
# 1    10016  2126863400             Italian      11/25/2014
# 2    11106  3478134702             Italian      10/03/2016
# 3    10314  7189839854             Chinese      05/17/2017
# 4    11209  7187019180            American      03/30/2017
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1  Violations were cited in the following area(s).            20F
# 2  Violations were cited in the following area(s).            10F
# 3  Violations were cited in the following area(s).            02G
# 4  Violations were cited in the following area(s).            04M
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0        Hot food item not held at or above 140Âº F.      Critical   30.0
# 1              Current letter grade card not posted.  Not Critical    NaN
# 2  Non-food contact surface improperly constructe...  Not Critical    2.0
# 3  Cold food item held above 41Âº F (smoked fish ...      Critical   46.0
# 4  Live roaches present in facility's food and/or...      Critical   18.0
#
#   GRADE GRADE DATE RECORD DATE  \
# 0   NaN        NaN  08/28/2017
# 1   NaN        NaN  08/28/2017
# 2   NaN        NaN  08/28/2017
# 3   NaN        NaN  08/28/2017
# 4   NaN        NaN  08/28/2017
#
#                                      INSPECTION TYPE
# 0              Cycle Inspection / Initial Inspection
# 1  Administrative Miscellaneous / Initial Inspection
# 2      Pre-permit (Operational) / Initial Inspection
# 3      Pre-permit (Operational) / Initial Inspection
# 4              Cycle Inspection / Initial Inspection

# %%
# See if there is any other value besides 08/28/2017 in thhe RECORD DATE
# IF THERE IS JUST ONE VALUE, DELETE THE COLUMN
nycdf['RECORD DATE'].value_counts()
# Out:
# 08/28/2017    399907
# Name: RECORD DATE, dtype: int64

# %%
# Remove the RECORD DATE column
nycdf = nycdf = nycdf[['CAMIS', 'DBA', 'BORO', 'ADDRESS', 'ZIPCODE', 'PHONE', 'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 
               'VIOLATION CODE', 'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE', 'GRADE DATE', 'INSPECTION TYPE']]
nycdf.head()
# Out:
#       CAMIS                      DBA           BORO            ADDRESS  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN  635 SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN  635 SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS      2507 BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND    11C HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN      8015 5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0    10016  2126863400             Italian      06/15/2015
# 1    10016  2126863400             Italian      11/25/2014
# 2    11106  3478134702             Italian      10/03/2016
# 3    10314  7189839854             Chinese      05/17/2017
# 4    11209  7187019180            American      03/30/2017
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1  Violations were cited in the following area(s).            20F
# 2  Violations were cited in the following area(s).            10F
# 3  Violations were cited in the following area(s).            02G
# 4  Violations were cited in the following area(s).            04M
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0        Hot food item not held at or above 140Âº F.      Critical   30.0
# 1              Current letter grade card not posted.  Not Critical    NaN
# 2  Non-food contact surface improperly constructe...  Not Critical    2.0
# 3  Cold food item held above 41Âº F (smoked fish ...      Critical   46.0
# 4  Live roaches present in facility's food and/or...      Critical   18.0
#
#   GRADE GRADE DATE                                    INSPECTION TYPE
# 0   NaN        NaN              Cycle Inspection / Initial Inspection
# 1   NaN        NaN  Administrative Miscellaneous / Initial Inspection
# 2   NaN        NaN      Pre-permit (Operational) / Initial Inspection
# 3   NaN        NaN      Pre-permit (Operational) / Initial Inspection
# 4   NaN        NaN              Cycle Inspection / Initial Inspection

# %%
# Reset Index without adding a column
nycdf = nycdf.reset_index(drop=True, inplace=False)
nycdf
# Out:
#            CAMIS                        DBA           BORO  \
# 0       40511702          NOTARO RESTAURANT      MANHATTAN
# 1       40511702          NOTARO RESTAURANT      MANHATTAN
# 2       50046354                   VITE BAR         QUEENS
# 3       50061389    TACK'S CHINESE TAKE OUT  STATEN ISLAND
# 4       41516263                 NO QUARTER       BROOKLYN
# ...          ...                        ...            ...
# 399902  41004284              CAFE CLASSICO      MANHATTAN
# 399903  40368318              MAGGIES PLACE      MANHATTAN
# 399904  50051468           Yong Kong Street      MANHATTAN
# 399905  41555297  RUBY FALLS NIGHTLIFE CAFE  STATEN ISLAND
# 399906  50016782             DUNKIN' DONUTS       BROOKLYN
#
#                     ADDRESS  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0         635 SECOND AVENUE    10016  2126863400             Italian
# 1         635 SECOND AVENUE    10016  2126863400             Italian
# 2             2507 BROADWAY    11106  3478134702             Italian
# 3           11C HOLDEN BLVD    10314  7189839854             Chinese
# 4             8015 5 AVENUE    11209  7187019180            American
# ...                     ...      ...         ...                 ...
# 399902  35 WEST   57 STREET    10019  2123555411       Jewish/Kosher
# 399903  21 EAST   47 STREET    10017  2127535757            American
# 399904        1000S 8TH AVE    10019  9176406083            Japanese
# 399905       45 PAGE AVENUE    10309  7189849888            American
# 399906      359 NEPTUNE AVE    11235  3477131057              Donuts
#
#        INSPECTION DATE                                           ACTION  \
# 0           06/15/2015  Violations were cited in the following area(s).
# 1           11/25/2014  Violations were cited in the following area(s).
# 2           10/03/2016  Violations were cited in the following area(s).
# 3           05/17/2017  Violations were cited in the following area(s).
# 4           03/30/2017  Violations were cited in the following area(s).
# ...                ...                                              ...
# 399902      01/28/2016  Violations were cited in the following area(s).
# 399903      02/29/2016  Violations were cited in the following area(s).
# 399904      01/05/2017  Violations were cited in the following area(s).
# 399905      09/19/2014  Violations were cited in the following area(s).
# 399906      11/15/2016  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 02B        Hot food item not held at or above 140Âº F.
# 1                 20F              Current letter grade card not posted.
# 2                 10F  Non-food contact surface improperly constructe...
# 3                 02G  Cold food item held above 41Âº F (smoked fish ...
# 4                 04M  Live roaches present in facility's food and/or...
# ...               ...                                                ...
# 399902            04C  Food worker does not use proper utensil to eli...
# 399903            04L  Evidence of mice or live mice present in facil...
# 399904            10B  Plumbing not properly installed or maintained;...
# 399905            10I  Single service item reused, improperly stored,...
# 399906            10F  Non-food contact surface improperly constructe...
#
#        CRITICAL FLAG  SCORE GRADE  GRADE DATE  \
# 0           Critical   30.0   NaN         NaN
# 1       Not Critical    NaN   NaN         NaN
# 2       Not Critical    2.0   NaN         NaN
# 3           Critical   46.0   NaN         NaN
# 4           Critical   18.0   NaN         NaN
# ...              ...    ...   ...         ...
# 399902      Critical   19.0   NaN         NaN
# 399903      Critical   11.0     A  02/29/2016
# 399904  Not Critical   25.0   NaN         NaN
# 399905  Not Critical   12.0     A  09/19/2014
# 399906  Not Critical    9.0     A  11/15/2016
#
#                                           INSPECTION TYPE
# 0                   Cycle Inspection / Initial Inspection
# 1       Administrative Miscellaneous / Initial Inspection
# 2           Pre-permit (Operational) / Initial Inspection
# 3           Pre-permit (Operational) / Initial Inspection
# 4                   Cycle Inspection / Initial Inspection
# ...                                                   ...
# 399902              Cycle Inspection / Initial Inspection
# 399903                   Cycle Inspection / Re-inspection
# 399904      Pre-permit (Operational) / Initial Inspection
# 399905                   Cycle Inspection / Re-inspection
# 399906              Cycle Inspection / Initial Inspection
#
# [399907 rows x 16 columns]

# %%
# Fill in all NaN and nan with "-"
# nycdf = nycdf.fillna("-")
# nycdf

# %% [markdown]
# # **_San Francisco Inspection_**

# %%
# San Francisco Inscpection CSV
sf = "Resources/restaurant-scores-live-standard.csv"
sf_df = pd.read_csv(sf)
sf_df
# Out:
#        business_id          business_name          business_address  \
# 0           101192           Cochinita #2  2 Marina Blvd Fort Mason
# 1            97975             BREADBELLY           1408 Clement St
# 2            92982  Great Gold Restaurant             3161 24th St.
# 3           101389                 HOMAGE         214 CALIFORNIA ST
# 4            85986           Pronto Pizza               798 Eddy St
# ...            ...                    ...                       ...
# 53968        89569     Blue Bottle Coffee              2 South Park
# 53969        99764              POKE KANA              65 CAMBON Dr
# 53970        84541           Philz Coffee             300 Folsom St
# 53971        91572      El Gran Taco Loco          4591 Mission St.
# 53972        89569     Blue Bottle Coffee              2 South Park
#
#        business_city business_state business_postal_code  business_latitude  \
# 0      San Francisco             CA                  NaN                NaN
# 1      San Francisco             CA                94118                NaN
# 2      San Francisco             CA                94110                NaN
# 3      San Francisco             CA                94111                NaN
# 4      San Francisco             CA                94109                NaN
# ...              ...            ...                  ...                ...
# 53968  San Francisco             CA                94107                NaN
# 53969  San Francisco             CA                94132                NaN
# 53970  San Francisco             CA                94105                NaN
# 53971  San Francisco             CA                94112                NaN
# 53972  San Francisco             CA                94107                NaN
#
#        business_longitude business_location  business_phone_number  ...  \
# 0                     NaN               NaN           1.415043e+10  ...
# 1                     NaN               NaN           1.415724e+10  ...
# 2                     NaN               NaN                    NaN  ...
# 3                     NaN               NaN           1.415488e+10  ...
# 4                     NaN               NaN                    NaN  ...
# ...                   ...               ...                    ...  ...
# 53968                 NaN               NaN                    NaN  ...
# 53969                 NaN               NaN                    NaN  ...
# 53970                 NaN               NaN                    NaN  ...
# 53971                 NaN               NaN                    NaN  ...
# 53972                 NaN               NaN                    NaN  ...
#
#                 inspection_type           violation_id  \
# 0                 New Ownership                    NaN
# 1         Routine - Unscheduled  97975_20190725_103124
# 2                 New Ownership                    NaN
# 3              New Construction                    NaN
# 4                 New Ownership  85986_20161011_103114
# ...                         ...                    ...
# 53968     Routine - Unscheduled  89569_20190506_103124
# 53969  New Ownership - Followup                    NaN
# 53970     Routine - Unscheduled  84541_20190506_103133
# 53971     Routine - Unscheduled  91572_20190506_103116
# 53972     Routine - Unscheduled  89569_20190506_103157
#
#                                    violation_description  risk_category  \
# 0                                                    NaN            NaN
# 1      Inadequately cleaned or sanitized food contact...  Moderate Risk
# 2                                                    NaN            NaN
# 3                                                    NaN            NaN
# 4                           High risk vermin infestation      High Risk
# ...                                                  ...            ...
# 53968  Inadequately cleaned or sanitized food contact...  Moderate Risk
# 53969                                                NaN            NaN
# 53970             Foods not protected from contamination  Moderate Risk
# 53971  Inadequate food safety knowledge or lack of ce...  Moderate Risk
# 53972  Food safety certificate or food handler card n...       Low Risk
#
#       Neighborhoods (old) Police Districts Supervisor Districts  \
# 0                     NaN              NaN                  NaN
# 1                     NaN              NaN                  NaN
# 2                     NaN              NaN                  NaN
# 3                     NaN              NaN                  NaN
# 4                     NaN              NaN                  NaN
# ...                   ...              ...                  ...
# 53968                 NaN              NaN                  NaN
# 53969                 NaN              NaN                  NaN
# 53970                 NaN              NaN                  NaN
# 53971                 NaN              NaN                  NaN
# 53972                 NaN              NaN                  NaN
#
#        Fire Prevention Districts  Zip Codes  Analysis Neighborhoods
# 0                            NaN        NaN                     NaN
# 1                            NaN        NaN                     NaN
# 2                            NaN        NaN                     NaN
# 3                            NaN        NaN                     NaN
# 4                            NaN        NaN                     NaN
# ...                          ...        ...                     ...
# 53968                        NaN        NaN                     NaN
# 53969                        NaN        NaN                     NaN
# 53970                        NaN        NaN                     NaN
# 53971                        NaN        NaN                     NaN
# 53972                        NaN        NaN                     NaN
#
# [53973 rows x 23 columns]

# %%
# Create Copy of original CSV
sfdf = sf_df.copy()

# %%
# Drop any duplicate rows.
sfdf = sfdf.drop_duplicates()

# Unselect unneeded columns business_latitude
sfdf = sfdf[['business_id', 'business_name', 'business_address', 'business_city','business_state', 'business_postal_code',
            'business_phone_number', 'inspection_id', 'inspection_date', 'inspection_score', 'inspection_type', 'violation_id', 
             'violation_description', 'risk_category']]

# Convert the 'business_phone_number' to str instead of float so the whole number is revealed.
sfdf['business_phone_number'] = sfdf['business_phone_number'].astype(str)

# Rename most of the columns with 'business_' since information given is about the business name.
sfdf = sfdf.rename(columns={'business_address': 'address',
                     'business_city': 'city',
                     'business_state': 'state',
                     'business_postal_code': 'postal_code',
                     'business_phone_number': 'phone_number'
                        })

sfdf.head()
# Out:
#    business_id          business_name                   address  \
# 0       101192           Cochinita #2  2 Marina Blvd Fort Mason
# 1        97975             BREADBELLY           1408 Clement St
# 2        92982  Great Gold Restaurant             3161 24th St.
# 3       101389                 HOMAGE         214 CALIFORNIA ST
# 4        85986           Pronto Pizza               798 Eddy St
#
#             city state postal_code   phone_number    inspection_id  \
# 0  San Francisco    CA         NaN  14150429222.0  101192_20190606
# 1  San Francisco    CA       94118  14157240859.0   97975_20190725
# 2  San Francisco    CA       94110            nan   92982_20170912
# 3  San Francisco    CA       94111  14154878161.0  101389_20190625
# 4  San Francisco    CA       94109            nan   85986_20161011
#
#            inspection_date  inspection_score        inspection_type  \
# 0  2019-06-06T00:00:00.000               NaN          New Ownership
# 1  2019-07-25T00:00:00.000              96.0  Routine - Unscheduled
# 2  2017-09-12T00:00:00.000               NaN          New Ownership
# 3  2019-06-25T00:00:00.000               NaN       New Construction
# 4  2016-10-11T00:00:00.000               NaN          New Ownership
#
#             violation_id                              violation_description  \
# 0                    NaN                                                NaN
# 1  97975_20190725_103124  Inadequately cleaned or sanitized food contact...
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4  85986_20161011_103114                       High risk vermin infestation
#
#    risk_category
# 0            NaN
# 1  Moderate Risk
# 2            NaN
# 3            NaN
# 4      High Risk

# %%
# Remove the decimal (.0) from phone_number
sfdf['phone_number'] = sfdf['phone_number'].str.strip(".0")

# Converted the datetime from the inspection_date to just the date.
sfdf['inspection_date'] = pd.to_datetime(sfdf['inspection_date'])

# Make violation_id unique by removing the 2 sets of numbers that are based from their inspection id. THis allows us to find
# similar results under the same violation_id.
sfdf['violation_id'] =sfdf['violation_id'].str[-6:] 

sfdf
# Out:
#        business_id          business_name                   address  \
# 0           101192           Cochinita #2  2 Marina Blvd Fort Mason
# 1            97975             BREADBELLY           1408 Clement St
# 2            92982  Great Gold Restaurant             3161 24th St.
# 3           101389                 HOMAGE         214 CALIFORNIA ST
# 4            85986           Pronto Pizza               798 Eddy St
# ...            ...                    ...                       ...
# 53968        89569     Blue Bottle Coffee              2 South Park
# 53969        99764              POKE KANA              65 CAMBON Dr
# 53970        84541           Philz Coffee             300 Folsom St
# 53971        91572      El Gran Taco Loco          4591 Mission St.
# 53972        89569     Blue Bottle Coffee              2 South Park
#
#                 city state postal_code phone_number    inspection_id  \
# 0      San Francisco    CA         NaN  14150429222  101192_20190606
# 1      San Francisco    CA       94118  14157240859   97975_20190725
# 2      San Francisco    CA       94110          nan   92982_20170912
# 3      San Francisco    CA       94111  14154878161  101389_20190625
# 4      San Francisco    CA       94109          nan   85986_20161011
# ...              ...   ...         ...          ...              ...
# 53968  San Francisco    CA       94107          nan   89569_20190506
# 53969  San Francisco    CA       94132          nan   99764_20190314
# 53970  San Francisco    CA       94105          nan   84541_20190506
# 53971  San Francisco    CA       94112          nan   91572_20190506
# 53972  San Francisco    CA       94107          nan   89569_20190506
#
#       inspection_date  inspection_score           inspection_type  \
# 0          2019-06-06               NaN             New Ownership
# 1          2019-07-25              96.0     Routine - Unscheduled
# 2          2017-09-12               NaN             New Ownership
# 3          2019-06-25               NaN          New Construction
# 4          2016-10-11               NaN             New Ownership
# ...               ...               ...                       ...
# 53968      2019-05-06              80.0     Routine - Unscheduled
# 53969      2019-03-14               NaN  New Ownership - Followup
# 53970      2019-05-06              92.0     Routine - Unscheduled
# 53971      2019-05-06              76.0     Routine - Unscheduled
# 53972      2019-05-06              80.0     Routine - Unscheduled
#
#       violation_id                              violation_description  \
# 0              NaN                                                NaN
# 1           103124  Inadequately cleaned or sanitized food contact...
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4           103114                       High risk vermin infestation
# ...            ...                                                ...
# 53968       103124  Inadequately cleaned or sanitized food contact...
# 53969          NaN                                                NaN
# 53970       103133             Foods not protected from contamination
# 53971       103116  Inadequate food safety knowledge or lack of ce...
# 53972       103157  Food safety certificate or food handler card n...
#
#        risk_category
# 0                NaN
# 1      Moderate Risk
# 2                NaN
# 3                NaN
# 4          High Risk
# ...              ...
# 53968  Moderate Risk
# 53969            NaN
# 53970  Moderate Risk
# 53971  Moderate Risk
# 53972       Low Risk
#
# [42023 rows x 14 columns]

# %%
# Reset Index without adding a column
sfdf = sfdf.reset_index(drop=True, inplace=False)
sfdf
# Out:
#        business_id          business_name                   address  \
# 0           101192           Cochinita #2  2 Marina Blvd Fort Mason
# 1            97975             BREADBELLY           1408 Clement St
# 2            92982  Great Gold Restaurant             3161 24th St.
# 3           101389                 HOMAGE         214 CALIFORNIA ST
# 4            85986           Pronto Pizza               798 Eddy St
# ...            ...                    ...                       ...
# 42018        89569     Blue Bottle Coffee              2 South Park
# 42019        99764              POKE KANA              65 CAMBON Dr
# 42020        84541           Philz Coffee             300 Folsom St
# 42021        91572      El Gran Taco Loco          4591 Mission St.
# 42022        89569     Blue Bottle Coffee              2 South Park
#
#                 city state postal_code phone_number    inspection_id  \
# 0      San Francisco    CA         NaN  14150429222  101192_20190606
# 1      San Francisco    CA       94118  14157240859   97975_20190725
# 2      San Francisco    CA       94110          nan   92982_20170912
# 3      San Francisco    CA       94111  14154878161  101389_20190625
# 4      San Francisco    CA       94109          nan   85986_20161011
# ...              ...   ...         ...          ...              ...
# 42018  San Francisco    CA       94107          nan   89569_20190506
# 42019  San Francisco    CA       94132          nan   99764_20190314
# 42020  San Francisco    CA       94105          nan   84541_20190506
# 42021  San Francisco    CA       94112          nan   91572_20190506
# 42022  San Francisco    CA       94107          nan   89569_20190506
#
#       inspection_date  inspection_score           inspection_type  \
# 0          2019-06-06               NaN             New Ownership
# 1          2019-07-25              96.0     Routine - Unscheduled
# 2          2017-09-12               NaN             New Ownership
# 3          2019-06-25               NaN          New Construction
# 4          2016-10-11               NaN             New Ownership
# ...               ...               ...                       ...
# 42018      2019-05-06              80.0     Routine - Unscheduled
# 42019      2019-03-14               NaN  New Ownership - Followup
# 42020      2019-05-06              92.0     Routine - Unscheduled
# 42021      2019-05-06              76.0     Routine - Unscheduled
# 42022      2019-05-06              80.0     Routine - Unscheduled
#
#       violation_id                              violation_description  \
# 0              NaN                                                NaN
# 1           103124  Inadequately cleaned or sanitized food contact...
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4           103114                       High risk vermin infestation
# ...            ...                                                ...
# 42018       103124  Inadequately cleaned or sanitized food contact...
# 42019          NaN                                                NaN
# 42020       103133             Foods not protected from contamination
# 42021       103116  Inadequate food safety knowledge or lack of ce...
# 42022       103157  Food safety certificate or food handler card n...
#
#        risk_category
# 0                NaN
# 1      Moderate Risk
# 2                NaN
# 3                NaN
# 4          High Risk
# ...              ...
# 42018  Moderate Risk
# 42019            NaN
# 42020  Moderate Risk
# 42021  Moderate Risk
# 42022       Low Risk
#
# [42023 rows x 14 columns]

# %%
# Fill in all NaN and nan with "-"
# sfdf = sfdf.fillna("-")
# sfdf['phone_number'] = sfdf['phone_number'].replace("nan", "-")
# sfdf

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'vineyard'
host = 'localhost'
port = 5432
database_name = 'inspections_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
engine.table_names()
# Out:
# C:\Users\Elizabeth\AppData\Local\Temp\ipykernel_31096\4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['chicago_inspection_data',
#  'la_inspection_data',
#  'la_violation_data',
#  'nyc_data',
#  'sf_data']

# %%
# load NYC inspection data
nycdf.to_sql(name='nyc_data', con=engine, if_exists='append', index=False)
# Out:
# 907

# %%
# load SF inspection data
sfdf.to_sql(name='sf_data', con=engine, if_exists='append', index=False)
# Out:
# 23
